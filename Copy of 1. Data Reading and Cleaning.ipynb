# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import xlrd

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/Skripsi Abdul Hakim/piton skripsi
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Skripsi Abdul Hakim/piton skripsi

# %% [markdown]
# # Read Data
#
# Read raw peatland data from 2018 to 2020. Data is in txt format with no dercribed feature name. Column name are given through readings.

# %%
df = pd.read_table("data/provinsi_sumsel (1).txt", delimiter=";",
                  names=['code', 'machine', 'provinsi', 'kabupaten', 'kecamatan', 'location', 'date', 'rain', 'soil', 'gwl', 'temp'],
                  header=None)
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,7,8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  code    machine          provinsi           kabupaten  \
# 0       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 1       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 2       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 3       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 4       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# ...               ...        ...               ...                 ...
# 660993  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660994  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660995  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# ...

# %%
df.dtypes
# Out:
# code         object
# machine       int64
# provinsi     object
# kabupaten    object
# kecamatan    object
# location     object
# date         object
# rain         object
# soil         object
# gwl          object
# temp         object
# dtype: object

# %% [markdown]
# # Change data type
#
# Convert rain, soil, gwl and temperature data type from object to float.

# %%
df['rain'] = pd.to_numeric(df['rain'], errors='coerce')
df['soil'] = pd.to_numeric(df['soil'], errors='coerce')
df['gwl'] = pd.to_numeric(df['gwl'], errors='coerce')
df['temp'] = pd.to_numeric(df['temp'], errors='coerce')

# %%
df.dtypes
# Out:
# code          object
# machine        int64
# provinsi      object
# kabupaten     object
# kecamatan     object
# location      object
# date          object
# rain         float64
# soil         float64
# gwl          float64
# temp         float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# code          0
# machine       0
# provinsi      0
# kabupaten     0
# kecamatan     0
# location      0
# date          0
# rain         45
# soil          2
# gwl           2
# temp          7
# dtype: int64

# %%
# Check each converted feature for missing values of inconsistent records

# %%
df[df['soil'].isnull()]
# Out:
#                  code    machine          provinsi           kabupaten  \
# 385087  BRG_160224_01  286823786  SUMATERA SELATAN  OGAN KOMERING ILIR
# 429289  BRG_160224_02  286823412  SUMATERA SELATAN  OGAN KOMERING ILIR
#
#         kecamatan      location date  rain  soil  gwl  temp
# 385087  PEDAMARAN  Cinta Jaya 1  Lat   NaN   NaN  NaN   NaN
# 429289  PEDAMARAN  Cinta Jaya 2    D   NaN   NaN  NaN   NaN

# %%
df[df['gwl'].isnull()]
# Out:
#                  code    machine          provinsi           kabupaten  \
# 385087  BRG_160224_01  286823786  SUMATERA SELATAN  OGAN KOMERING ILIR
# 429289  BRG_160224_02  286823412  SUMATERA SELATAN  OGAN KOMERING ILIR
#
#         kecamatan      location date  rain  soil  gwl  temp
# 385087  PEDAMARAN  Cinta Jaya 1  Lat   NaN   NaN  NaN   NaN
# 429289  PEDAMARAN  Cinta Jaya 2    D   NaN   NaN  NaN   NaN

# %%
df[df['temp'].isnull()]
# Out:
#                  code    machine          provinsi           kabupaten  \
# 202658  BRG_160214_02  286827117  SUMATERA SELATAN  OGAN KOMERING ILIR
# 244915  BRG_160214_03  286827062  SUMATERA SELATAN  OGAN KOMERING ILIR
# 251913  BRG_160214_03  286827062  SUMATERA SELATAN  OGAN KOMERING ILIR
# 385087  BRG_160224_01  286823786  SUMATERA SELATAN  OGAN KOMERING ILIR
# 421258  BRG_160224_02  286823412  SUMATERA SELATAN  OGAN KOMERING ILIR
# 429289  BRG_160224_02  286823412  SUMATERA SELATAN  OGAN KOMERING ILIR
# 503581  BRG_160609_01  286823560  SUMATERA SELATAN      MUSI BANYUASIN
#
#             kecamatan               location          date  rain  soil    gwl  \
# 202658    AIR SUGIHAN  Padang Sugihan 2 (SM)  191229042000   0.0   0.0  2.136
# 244915    AIR SUGIHAN  Padang Sugihan 3 (SM)  191020105000   0.0   0.0  0.952
# 251913    AIR SUGIHAN  Padang Sugihan 3 (SM)  191205023000   0.0   0.0  1.533
# 385087      PEDAMARAN           Cinta Jaya 1           Lat   NaN   NaN    NaN
# ...

# %%
df[df['rain'].isnull()]
# Out:
#                  code    machine          provinsi           kabupaten  \
# 900     BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 53343   BRG_160205_02  286823691  SUMATERA SELATAN  OGAN KOMERING ILIR
# 66704   BRG_160205_02  286823691  SUMATERA SELATAN  OGAN KOMERING ILIR
# 70732   BRG_160205_02  286823691  SUMATERA SELATAN  OGAN KOMERING ILIR
# 155050  BRG_160214_02  286827117  SUMATERA SELATAN  OGAN KOMERING ILIR
# 156003  BRG_160214_02  286827117  SUMATERA SELATAN  OGAN KOMERING ILIR
# 162378  BRG_160214_02  286827117  SUMATERA SELATAN  OGAN KOMERING ILIR
# 169894  BRG_160214_02  286827117  SUMATERA SELATAN  OGAN KOMERING ILIR
# 205546  BRG_160214_03  286827062  SUMATERA SELATAN  OGAN KOMERING ILIR
# 209396  BRG_160214_03  286827062  SUMATERA SELATAN  OGAN KOMERING ILIR
# 215018  BRG_160214_03  286827062  SUMATERA SELATAN  OGAN KOMERING ILIR
# 215133  BRG_160214_03  286827062  SUMATERA SELATAN  OGAN KOMERING ILIR
# ...

# %% [markdown]
# # Remove inconsistent reading

# %%
df.iloc[385087]
# Out:
# code              BRG_160224_01
# machine               286823786
# provinsi       SUMATERA SELATAN
# kabupaten    OGAN KOMERING ILIR
# kecamatan             PEDAMARAN
# location           Cinta Jaya 1
# date                        Lat
# rain                        NaN
# soil                        NaN
# gwl                         NaN
# temp                        NaN
# Name: 385087, dtype: object

# %%
df.iloc[429289]
# Out:
# code              BRG_160224_02
# machine               286823412
# provinsi       SUMATERA SELATAN
# kabupaten    OGAN KOMERING ILIR
# kecamatan             PEDAMARAN
# location           Cinta Jaya 2
# date                          D
# rain                        NaN
# soil                        NaN
# gwl                         NaN
# temp                        NaN
# Name: 429289, dtype: object

# %%
df = df.drop([385087, 429289])

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# # Convert date

# %%
df['date'] = pd.to_datetime(df['date'], format='%y%m%d%H%M%S')
df
# Out:
#                  code    machine          provinsi           kabupaten  \
# 0       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 1       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 2       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 3       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 4       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# ...               ...        ...               ...                 ...
# 660991  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660992  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660993  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660994  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660995  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
#
#               kecamatan           location                date  rain  soil  \
# ...

# %%
df.dtypes
# Out:
# code                 object
# machine               int64
# provinsi             object
# kabupaten            object
# kecamatan            object
# location             object
# date         datetime64[ns]
# rain                float64
# soil                float64
# gwl                 float64
# temp                float64
# dtype: object

# %% [markdown]
# # Reduce columns

# %%
# df.to_pickle("data_clean_duplicate.pkl")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660996 entries, 0 to 660995
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   code       660996 non-null  object
#  1   machine    660996 non-null  int64
#  2   provinsi   660996 non-null  object
#  3   kabupaten  660996 non-null  object
#  4   kecamatan  660996 non-null  object
#  5   location   660996 non-null  object
#  6   date       660996 non-null  datetime64[ns]
#  7   rain       660953 non-null  float64
#  8   soil       660996 non-null  float64
#  9   gwl        660996 non-null  float64
#  10  temp       660991 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 55.5+ MB

# %%
df = df.drop(['code', 'machine', 'provinsi', 'kabupaten', 'kecamatan'], axis=1)
df
# Out:
#                  location                date  rain  soil    gwl  temp
# 0       Kedaton (Demplot) 2018-11-09 18:00:00   0.0  88.2  0.148  28.3
# 1       Kedaton (Demplot) 2018-11-09 18:10:00   0.2  87.8  0.156  28.6
# 2       Kedaton (Demplot) 2018-11-09 18:20:00   0.0  87.4  0.166  28.6
# 3       Kedaton (Demplot) 2018-11-09 18:30:00   0.0  87.4  0.166  28.9
# 4       Kedaton (Demplot) 2018-11-09 18:40:00   0.0  87.0  0.175  28.9
# ...                   ...                 ...   ...   ...    ...   ...
# 660991       Karang agung 2020-01-10 03:10:00   0.0  28.8  1.733  29.5
# 660992       Karang agung 2020-01-10 03:20:00   0.0  28.7  1.736  28.9
# 660993       Karang agung 2020-01-10 03:30:00   0.0  29.0  1.733  30.1
# 660994       Karang agung 2020-01-10 03:30:00   0.0  29.0  1.731  29.8
# 660995       Karang agung 2020-01-10 03:40:00   0.0  29.0  1.733  30.1
#
# [660996 rows x 6 columns]

# %%
# df.to_pickle("data_clean_reduced_duplicate.pkl")

# %% [markdown]
# # Remove duplicates

# %% [markdown]
# Duplicate data with same datetime with same code and machine will be removed

# %%
names = list(df['location'].unique())
names
# Out:
# ['Kedaton (Demplot)',
#  'Kedaton',
#  'Padang Sugihan 1 (SM)',
#  'Padang Sugihan 2 (SM)',
#  'Padang Sugihan 3 (SM)',
#  'Air Rumbai',
#  'Cinta Jaya 1',
#  'Cinta Jaya 2',
#  'Cinta Jaya 3',
#  'Muara Medak 1',
#  'Muara Medak 2',
#  'Karang agung']

# %%
for i in names:
    raw_data = pd.read_pickle('raw/' + i + '.pkl')
    raw_data = raw_data.drop_duplicates(subset=['date'], keep='last')
    raw_data = raw_data.reset_index(drop=True)
    raw_data = raw_data.set_index('date')
    raw_data = raw_data.asfreq('10T', fill_value=np.nan)
    raw_data.reset_index(inplace=True)
    raw_data['location'] = i
    
    raw_data.to_pickle("date/" + i + ".pkl")

# %%
# %who
# Out:
# datetime	 df	 drive	 i	 names	 np	 pd	 plt	 raw_data
# xlrd
