# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
n = [0, 1,2,3,4,5,6]
m = [3,3,3,3]
x = [3,4,5,6]

plt.plot([3,4,5,6], [3,3,3,6], color="red", linestyle='--', marker="^", label="LOCF")

plt.plot([3,6], [3,6], color="grey", linestyle="dotted", label="Expected value")

plt.plot([0,1,2,3], [0,1,2,3], color="blue", marker='o', label="Actual value")
plt.plot([6,7,8,9], [6,7,8,9], color="blue", marker='o')

plt.legend(loc="upper left")
plt.axis('off')
plt.savefig("LOCF.png", bbox_inches='tight')

# %%
n = [0, 1,2,3,4,5,6]
m = [3,3,3,3]
x = [3,4,5,6]

plt.plot([3,4,5,6], [3,6,6,6], color="red", linestyle='--', marker="^", label="NOCB")

plt.plot([3,6], [3,6], color="grey", linestyle="dotted", label="Expected value")

plt.plot([0,1,2,3], [0,1,2,3], color="blue", marker='o', label="Actual value")
plt.plot([6,7,8,9], [6,7,8,9], color="blue", marker='o')

plt.legend(loc="upper left")
plt.axis('off')
plt.savefig("NOCB.png", bbox_inches='tight')
