# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import os.path
import os
from datetime import datetime
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation
from keras.models import load_model
from xgboost import XGBRegressor
from sklearn.feature_selection import SelectFromModel
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  3

# %%
os.getcwd()
# Out:
# '/workspace/IFA_DIR/TMA'

# %%
date_parser = lambda x: datetime.strptime(x, '%y%m%d%H%M%S')
df = pd.read_csv("data/cinta1.csv", parse_dates = ['date'], date_parser = date_parser, sep=';')
df.head()
# Out:
#                  date           code  no_machine              prov  \
# 0 2018-11-10 11:40:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 1 2018-11-10 11:50:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 2 2018-11-10 12:00:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 3 2018-11-10 12:10:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 4 2018-11-10 12:20:00  BRG_160224_01   286823786  SUMATERA SELATAN
#
#                   kab        kec        lokasi precip soil_moisture     gwl  \
# 0  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1    0,4           3,2  -1,381
# 1  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,379
# 2  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,372
# 3  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,372
# 4  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,364
#
#    temp        lat      long
# 0  30,7  -3,392495  104,9775
# 1  30,7  -3,392495  104,9775
# 2  30,7  -3,392495  104,9775
# 3  31,1  -3,392495  104,9775
# 4  31,1  -3,392495  104,9775

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# code                     object
# no_machine                int64
# prov                     object
# kab                      object
# kec                      object
# lokasi                   object
# precip                   object
# soil_moisture            object
# gwl                      object
# temp                     object
# lat                      object
# long                     object
# dtype: object

# %%
df = df.drop(['no_machine', 'prov', 'kab', 'kec', 'lat', 'long'], 1)

# %%
df['code'].unique()
# Out:
# array(['BRG_160224_01'], dtype=object)

# %%
df['lokasi'].unique()
# Out:
# array(['Cinta Jaya 1'], dtype=object)

# %%
df['precip'] = df['precip'].str.replace(",", ".")
df['soil_moisture'] = df['soil_moisture'].str.replace(",", ".")
df['gwl'] = df['gwl'].str.replace(",", ".")
df['temp'] = df['temp'].str.replace(",", ".")

# %%
df['precip'] = df['precip'].astype(float)
df['soil_moisture'] = df['soil_moisture'].astype(float)
df['gwl'] = df['gwl'].astype(float)
df['temp'] = df['temp'].astype(float)

# %%
df_kedaton_demplot = df[df['lokasi'] == 'Kedaton (Demplot)']
df_kedaton= df[df['lokasi'] == 'Kedaton']
df_padang_sugihan_1 = df[df['lokasi'] == 'Padang Sugihan 1 (SM)']
df_padang_sugihan_2 = df[df['lokasi'] == 'Padang Sugihan 2 (SM)']
df_padang_sugihan_3 = df[df['lokasi'] == 'Padang Sugihan 3 (SM)']
df_air_rumbai = df[df['lokasi'] == 'Air Rumbai']
df_cinta_jaya_1 = df[df['lokasi'] == 'Cinta Jaya 1']
df_cinta_jaya_2 = df[df['lokasi'] == 'Cinta Jaya 2']
df_cinta_jaya_3 = df[df['lokasi'] == 'Cinta Jaya 3']
df_muara_medak_1 = df[df['lokasi'] == 'Muara Medak 1']
df_muara_medak_2 = df[df['lokasi'] == 'Muara Medak 2']
df_karang_agung = df[df['lokasi'] == 'Karang agung']

# %%
df[df.duplicated('date', keep=False)].head(10)
# Out:
#                    date           code        lokasi  precip  soil_moisture  \
# 172 2018-11-11 16:40:00  BRG_160224_01  Cinta Jaya 1     7.4            6.7
# 173 2018-11-11 16:50:00  BRG_160224_01  Cinta Jaya 1    12.4           10.0
# 174 2018-11-11 17:00:00  BRG_160224_01  Cinta Jaya 1    12.2           13.8
# 175 2018-11-11 17:00:00  BRG_160224_01  Cinta Jaya 1     0.0           13.9
# 176 2018-11-11 17:10:00  BRG_160224_01  Cinta Jaya 1     3.4           13.2
# 177 2018-11-11 17:20:00  BRG_160224_01  Cinta Jaya 1     4.2           12.9
# 178 2018-11-11 17:30:00  BRG_160224_01  Cinta Jaya 1     1.2           12.3
# 179 2018-11-11 17:40:00  BRG_160224_01  Cinta Jaya 1     0.2           11.3
# 180 2018-11-11 17:50:00  BRG_160224_01  Cinta Jaya 1     0.0           10.4
# 181 2018-11-11 16:40:00  BRG_160224_01  Cinta Jaya 1     7.4            6.7
#
#        gwl  temp
# 172 -0.666  30.4
# 173 -0.632  30.4
# 174 -0.566  30.4
# 175 -0.563  30.4
# 176 -0.509  30.7
# 177 -0.463  30.7
# 178 -0.414  30.7
# 179 -0.375  30.4
# 180 -0.361  30.4
# 181 -0.666  30.4

# %%
df[df.duplicated('date', keep=False)].tail(10)
# Out:
#                      date           code        lokasi  precip  soil_moisture  \
# 84358 2020-01-09 23:00:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84359 2020-01-09 23:00:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84363 2020-01-09 23:40:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84364 2020-01-09 23:40:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84365 2020-01-09 23:50:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84366 2020-01-09 23:50:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84367 2020-01-10 00:00:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84368 2020-01-10 00:00:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84382 2020-01-10 02:20:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
# 84383 2020-01-10 02:20:00  BRG_160224_01  Cinta Jaya 1     0.0           29.0
#
#          gwl  temp
# 84358 -0.881  29.8
# 84359 -0.881  29.8
# 84363 -0.878  29.5
# 84364 -0.878  29.5
# 84365 -0.878  29.5
# 84366 -0.886  29.5
# 84367 -0.886  29.5
# 84368 -0.886  29.5
# 84382 -0.878  29.5
# 84383 -0.881  29.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84386 entries, 0 to 84385
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           84386 non-null  datetime64[ns]
#  1   code           84386 non-null  object
#  2   lokasi         84386 non-null  object
#  3   precip         84386 non-null  float64
#  4   soil_moisture  84386 non-null  float64
#  5   gwl            84386 non-null  float64
#  6   temp           84386 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 4.5+ MB

# %%
df.plot(subplots=True, figsize=(25,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    agg = pd.concat(cols, axis=1)
    agg.columns = names

    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def min_max(variable):
  res = (variable - variable.min())/(variable.max() - variable.min())
  return res

# %%
date_parser = lambda x: datetime.strptime(x, '%y%m%d%H%M%S')
df = pd.read_csv("data/cinta1.csv", parse_dates = ['date'], date_parser = date_parser, sep=';')
df.head()
# Out:
#                  date           code  no_machine              prov  \
# 0 2018-11-10 11:40:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 1 2018-11-10 11:50:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 2 2018-11-10 12:00:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 3 2018-11-10 12:10:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 4 2018-11-10 12:20:00  BRG_160224_01   286823786  SUMATERA SELATAN
#
#                   kab        kec        lokasi precip soil_moisture     gwl  \
# 0  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1    0,4           3,2  -1,381
# 1  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,379
# 2  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,372
# 3  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,372
# 4  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0           3,2  -1,364
#
#    temp        lat      long
# 0  30,7  -3,392495  104,9775
# 1  30,7  -3,392495  104,9775
# 2  30,7  -3,392495  104,9775
# 3  31,1  -3,392495  104,9775
# 4  31,1  -3,392495  104,9775

# %%
df.tail()
# Out:
#                      date           code  no_machine              prov  \
# 84381 2020-01-10 02:10:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 84382 2020-01-10 02:20:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 84383 2020-01-10 02:20:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 84384 2020-01-10 02:30:00  BRG_160224_01   286823786  SUMATERA SELATAN
# 84385 2020-01-10 02:40:00  BRG_160224_01   286823786  SUMATERA SELATAN
#
#                       kab        kec        lokasi precip soil_moisture  \
# 84381  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0            29
# 84382  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0            29
# 84383  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0            29
# 84384  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0          28,6
# 84385  OGAN KOMERING ILIR  PEDAMARAN  Cinta Jaya 1      0            29
#
#           gwl  temp        lat      long
# 84381  -0,886  29,5  -3,392495  104,9775
# 84382  -0,878  29,5  -3,392495  104,9775
# 84383  -0,881  29,5  -3,392495  104,9775
# 84384  -0,878  29,5  -3,392495  104,9775
# 84385  -0,876  29,5  -3,392495  104,9775

# %%
df.drop(['lat', 'long'], 1, inplace = True)
df.drop_duplicates(subset = ['date', 'code', 'no_machine', 'prov', 'kab', 'kec', 'lokasi', 'precip', 'soil_moisture', 'gwl', 'temp'], keep = 'first', inplace = True)
df.drop(['code', 'no_machine', 'prov', 'kab', 'kec', 'lokasi'], 1, inplace = True)
df = df[['date', 'precip', 'soil_moisture', 'temp', 'gwl']]

# %%
df['precip'] = df['precip'].str.replace(",", ".")
df['soil_moisture'] = df['soil_moisture'].str.replace(",", ".")
df['gwl'] = df['gwl'].str.replace(",", ".")
df['temp'] = df['temp'].str.replace(",", ".")

# %%
df['precip'] = df['precip'].astype(float)
df['soil_moisture'] = df['soil_moisture'].astype(float)
df['gwl'] = df['gwl'].astype(float)
df['temp'] = df['temp'].astype(float)

# %%
df = df.groupby('date').agg({
    'precip': 'mean',
    'soil_moisture': 'mean',
    'gwl': 'mean',
    'temp': 'mean'
})

# %%
print(':: MEMERIKSA JIKA [df] MASIH MEMILIKI NILAI YANG HILANG:', end=' ')
print(f'{df.isnull().values.any()}')
# Out:
# :: MEMERIKSA JIKA [df] MASIH MEMILIKI NILAI YANG HILANG: False

# %%
print(':: MENGISI NILAI HILANG MENGGUNAKAN METODE INTERPOLASI LINEAR')
df.interpolate(method='linear', inplace=True)
df.bfill(inplace=True) # Mengatasi nilai hilang pada index [0, 1]
# Out:
# :: MENGISI NILAI HILANG MENGGUNAKAN METODE INTERPOLASI LINEAR

# %%
print(':: STATISTIK DESKRIPTIF [df]')
df.describe()
# Out:
# :: STATISTIK DESKRIPTIF [df]
#              precip  soil_moisture           gwl          temp
# count  53324.000000   53324.000000  53324.000000  53324.000000
# mean       0.021989      23.382290     -0.609109     30.768958
# std        1.104083      31.360124      0.446020      1.320044
# min        0.000000       0.100000     -2.150000     15.200000
# 25%        0.000000       4.400000     -1.058500     29.800000
# 50%        0.000000       7.900000     -0.629000     30.700000
# 75%        0.000000      23.000000     -0.202000     31.700000
# max      175.800000      92.500000      0.309000     34.200000

# %%
print(':: STATISTIK DESKRIPTIF [TMA]')
df.describe().T.drop(['count', '25%', '75%'], axis=1)
# Out:
# :: STATISTIK DESKRIPTIF [TMA]
#                     mean        std    min     50%      max
# precip          0.021989   1.104083   0.00   0.000  175.800
# soil_moisture  23.382290  31.360124   0.10   7.900   92.500
# gwl            -0.609109   0.446020  -2.15  -0.629    0.309
# temp           30.768958   1.320044  15.20  30.700   34.200

# %%
import seaborn as sns
g = sns.pairplot(df)
g.fig.set_size_inches(15,15)

# %%
sns.boxplot(x=df['precip'])
# Out:
# <AxesSubplot:xlabel='precip'>

# %%
sns.boxplot(x=df['gwl'])
# Out:
# <AxesSubplot:xlabel='gwl'>

# %%
sns.boxplot(x=df['soil_moisture'])
# Out:
# <AxesSubplot:xlabel='soil_moisture'>

# %%
df.loc[df['soil_moisture'] >= 40, 'soil_moisture'] = np.nan

# %%
df.loc[df['soil_moisture'] <= 28, 'soil_moisture'] = np.nan

# %%
sns.boxplot(x=df['temp'])
# Out:
# <AxesSubplot:xlabel='temp'>

# %%
sns.boxplot(x=df['temp'])
# Out:
# <AxesSubplot:xlabel='temp'>

# %%
sns.boxplot(x=df['soil_moisture'])
# Out:
# <AxesSubplot:xlabel='soil_moisture'>

# %%
print(':: MEMERIKSA JIKA [df] MASIH MEMILIKI NILAI YANG HILANG:', end=' ')
print(f'{df.isnull().values.any()}')
# Out:
# :: MEMERIKSA JIKA [df] MASIH MEMILIKI NILAI YANG HILANG: True

# %%
print(':: MENGISI NILAI HILANG MENGGUNAKAN METODE INTERPOLASI LINEAR')
df.interpolate(method='linear', inplace=True)
df.bfill(inplace=True) # Mengatasi nilai hilang pada index [0, 1]
# Out:
# :: MENGISI NILAI HILANG MENGGUNAKAN METODE INTERPOLASI LINEAR

# %%
df.plot(subplots=True, figsize=(25,10))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %%
df.loc[df['gwl'] <= -1.9, 'gwl'] = np.nan

# %%
df.plot(subplots=True, figsize=(25,10))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %%
df.loc[df['temp'] <= 20, 'temp'] = np.nan

# %%
df.plot(subplots=True, figsize=(25,10))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %%
df['gwl'].fillna(value = df['gwl'].mean(), inplace=True)
df['soil_moisture'].fillna(value = df['soil_moisture'].mean(), inplace=True)
df['temp'].fillna(value = df['temp'].mean(), inplace=True)

# %%
df['soil_moisture'].interpolate().plot()

# %%
df.plot(subplots=True, figsize=(25,10))

# %%
df.plot(subplots=True, figsize=(25,10))

# %%
#mengisi kekosongan dengan bfiil 

#data = df.fillna(method='ffill').fillna(method='bfill')

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    agg = pd.concat(cols, axis=1)
    agg.columns = names

    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def min_max(variable):
  res = (variable - variable.min())/(variable.max() - variable.min())
  return res

# %%
date_parser = lambda x: datetime.strptime(x, '%y%m%d%H%M%S')
df = pd.read_csv("data/cinta1.csv", parse_dates = ['date'], date_parser = date_parser, sep=';')
df.head()

# %%
df.drop(['lat', 'long'], 1, inplace = True)
df.drop_duplicates(subset = ['date', 'code', 'no_machine', 'prov', 'kab', 'kec', 'lokasi', 'precip', 'soil_moisture', 'gwl', 'temp'], keep = 'first', inplace = True)
df.drop(['code', 'no_machine', 'prov', 'kab', 'kec', 'lokasi'], 1, inplace = True)
df = df[['date', 'precip', 'soil_moisture', 'temp', 'gwl']]

# %%
df['precip'] = df['precip'].str.replace(",", ".")
df['soil_moisture'] = df['soil_moisture'].str.replace(",", ".")
df['gwl'] = df['gwl'].str.replace(",", ".")
df['temp'] = df['temp'].str.replace(",", ".")

# %%
df['precip'] = df['precip'].astype(float)
df['soil_moisture'] = df['soil_moisture'].astype(float)
df['gwl'] = df['gwl'].astype(float)
df['temp'] = df['temp'].astype(float)

# %%
df = df.groupby('date').agg({
    'precip': 'mean',
    'soil_moisture': 'mean',
    'gwl': 'mean',
    'temp': 'mean'
})

# %%
df.head()

# %%
df.loc[df['gwl'] <= -2.0, 'gwl'] = np.nan
df.loc[df['temp'] <= 20, 'temp'] = np.nan

# %%
df.isna().sum()

# %%
df['gwl'].fillna(value = df['gwl'].mean(), inplace=True)
df['soil_moisture'].fillna(value = df['soil_moisture'].mean(), inplace=True)
df['temp'].fillna(value = df['temp'].mean(), inplace=True)

# %%
daterange_total = pd.date_range(start=df.index.min(), 
                                end=df.index.max(), 
                                freq="10T")
daterange_total.difference(df.index)

# %%
df.plot(subplots=True, figsize=(25,10))

# %%
min_gwl_df = df['gwl'].min()
max_gwl_df = df['gwl'].max()

df['precip'] = min_max(df['precip'])
df['soil_moisture'] = min_max(df['soil_moisture'])
df['temp'] = min_max(df['temp'])
df['gwl'] = min_max(df['gwl'])
df = df.reindex(columns=['gwl', 'precip', 'soil_moisture', 'temp'])
scaled_df = df.values

# %%
df.plot(subplots=True, figsize=(25,10))

# %%
timestep = 144
n_features = 4

# %%
reframed_df = series_to_supervised(scaled_df, timestep, 1)
reframed_df = reframed_df.iloc[:, :-3]
print(reframed_df.head())

# %%
new_df = pd.DataFrame(reframed_df)
y = new_df.iloc[:, -1:]
x = new_df.iloc[:, :-1]

# %%
model = XGBRegressor()
model.fit(x, y)

# %%
thresholds = np.sort(model.feature_importances_)
selection = SelectFromModel(model, threshold=0, prefit=True)

# %%
feature_idx = selection.get_support()
selected_dataset = selection.transform(x)
print(selected_dataset.shape)

# %%
train_ind_df = int(len(reframed_df)*0.8)

reframed_df = x.values
train_df = reframed_df[:train_ind_df, :]
test_df = reframed_df[train_ind_df:, :]

n_obs = timestep * n_features
train_X, train_y = train_df[:, :n_obs], train_df[:, -1]
test_X, test_y = test_df[:, :n_obs], test_df[:, -1]

# %%
train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

# %%
#epoch = [25, 50]
#unit_1 = [10, 30, 50]
#dropout_1 = [0.2, 0.4, 0.6]
#unit_2 = [10, 30, 50]
#dropout_2 = [0.2, 0.4, 0.6]
#dense = [100, 300, 500]
epoch = [25, 50]
unit_1 = [10]
dropout_1 = [0.2]
unit_2 = [10]
dropout_2 = [0.2]
dense = [100]
result = pd.DataFrame(columns=["model_name",
                               "rmse",
                               "rsquare",
                               "mae"])

# %%
for a in epoch:
    for b in unit_1:
        for c in dropout_1:
            for d in dense:
                for e in unit_2:
                    for f in dropout_2:
                        model = Sequential()
                        model.add(LSTM(b, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
                        model.add(Dropout(c))
                        model.add(Dense(d, activation='relu'))
                        model.add(LSTM(e, return_sequences=False))
                        model.add(Dropout(f))
                        model.add(Dense(1))
                        model.compile(optimizer='adam', loss='mean_squared_error',
                                      metrics=['mse', 'mae', 'mape'])
                        model.fit(train_X, train_y, epochs=a, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
                        model_name = "SAVE_MODEL/" + "model_" + str(a) + "_" + str(b) + "_" + str(c) + "_" + str(d) + "_" + str(e) + "_" + str(f) + ".h5"
                        model.save("%s" % str(model_name))
                        
                        ypred = model.predict(test_X)
                        inv_ypred = ypred.flatten()*(max_gwl_df - min_gwl_df) + min_gwl_df
                        
                        inv_yact = test_y*(max_gwl_df - min_gwl_df) + min_gwl_df
                        
                        rmse = sqrt(mean_squared_error(inv_yact, inv_ypred))
                        rsquare = r2_score(inv_yact, inv_ypred)
                        mae = mean_absolute_error(inv_yact, inv_ypred)
                        
                        df= pd.DataFrame({"model_name": str(model_name),
                                          "rmse": rmse,
                                          "rsquare": rsquare,
                                          "mae": mae}, index=[0])
                        
                        result = result.append(df, ignore_index=True)
                                
                        tf.keras.backend.clear_session()

# %%
print(result)

# %%
model = load_model("SAVE_MODEL/model_50_10_0.2_100_10_0.2.h5")

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
ypred = model.predict(test_X)
inv_ypred = ypred.flatten()*(max_gwl_df - min_gwl_df) + min_gwl_df

# %%
inv_yact = test_y*(max_gwl_df - min_gwl_df) + min_gwl_df

# %%
rmse = sqrt(mean_squared_error(inv_yact, inv_ypred))
rsquare = r2_score(inv_yact, inv_ypred)
mae = mean_absolute_error(inv_yact, inv_ypred)
print('Test RMSE: %.5f' % rmse)
print('Test R-Squared: %.5f' % rsquare)
print('Test MAE: %.5f' % mae)

# %%
len(df.index[train_ind_df:])

# %%
df_result = pd.DataFrame({
    'date': df.index[train_ind_df+144:],
    'actual': inv_yact,
    'predicted': inv_ypred
})

# %%
plt.figure(figsize=(19, 7))
plt.plot(df_result['date'], df_result['predicted'], 'b-', label = 'PRED')
plt.plot(df_result['date'], df_result['actual'], 'r-', label = 'ACT')
plt.xlabel('Date')
plt.ylabel('GWL')
plt.title('GRAFIK GWL DATA TEST')
plt.legend();

# %%
def plot_pred(test_X, model, model_name):
  ypred = model.predict(test_X)
  inv_ypred = ypred.flatten()*(max_gwl_df - min_gwl_df) + min_gwl_df
  
  inv_yact = test_y*(max_gwl_df - min_gwl_df) + min_gwl_df

  len(df.index[train_ind_df:])

  df_result = pd.DataFrame({
      'date': df.index[train_ind_df+144:],
      'actual': inv_yact,
      'predicted': inv_ypred
      })
  
  plt.figure(figsize=(19, 7))
  plt.plot(df_result['date'], df_result['predicted'], 'b-', label = 'PRED')
  plt.plot(df_result['date'], df_result['actual'], 'r-', label = 'ACT')
  plt.legend()
  plt.xlabel('Date')
  plt.ylabel('GWL')
  plt.title('GRAFIK GWL DATA TEST')
  plt_predname = "plot/predict/" + str(model_name) + ".png"
  print(plt_predname)
  plt.savefig("%s" % str(plt_predname))

  plt.close()
