# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import xlrd

# %% [markdown]
# Reference
#
# 1. https://medium.com/bukalapak-data/time-series-anomaly-detection-simple-yet-powerful-approaches-4449ffe1ca12
# 2. https://blog.paperspace.com/anomaly-detection-isolation-forest/

# %% [markdown]
# # Read Data (Test : Cinta Jaya 1)

# %%
location = "Cinta Jaya 1"
df = pd.read_pickle("clean/" + location + ".pkl")
df
# Out:
#            location                date  rain  soil    gwl  temp
# 0      Cinta Jaya 1 2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 1      Cinta Jaya 1 2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2      Cinta Jaya 1 2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 3      Cinta Jaya 1 2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 4      Cinta Jaya 1 2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...             ...                 ...   ...   ...    ...   ...
# 53319  Cinta Jaya 1 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 53320  Cinta Jaya 1 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 53321  Cinta Jaya 1 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 53322  Cinta Jaya 1 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 53323  Cinta Jaya 1 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# [53324 rows x 6 columns]

# %%
df = df.drop(['location'], axis=1)
df = df.set_index('date')
df
# Out:
#                      rain  soil    gwl  temp
# date
# 2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...                   ...   ...    ...   ...
# 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# [53324 rows x 4 columns]

# %% [markdown]
# # Adjust Offset Readings

# %%
data_offset = pd.read_excel('data/OFFSET.xlsx', engine='openpyxl')
data_offset
# Out:
#     No           Kode                  Desaa        Kecamatan  \
# 0    1  BRG_160205_01      KEDATON (DEMPLOT)  KOTA KAYU AGUNG
# 1    2  BRG_160205_02                KEDATON        PEDAMARAN
# 2    3  BRG_160214_01  PADANG SUGIHAN 1 (SM)  PANGKALAN LAPAM
# 3    4  BRG_160214_02  PADANG SUGIHAN 2 (SM)      AIR SUGIHAN
# 4    5  BRG_160214_03  PADANG SUGIHAN 3 (SM)      AIR SUGIHAN
# 5    6  BRG_160219_02             AIR RUMBAI  PANGKALAN LAPAM
# 6    7  BRG_160224_01           CINTA JAYA 1        PEDAMARAN
# 7    8  BRG_160224_02           CINTA JAYA 2        PEDAMARAN
# 8    9  BRG_160224_03           CINTA JAYA 3        PEDAMARAN
# 9   10  BRG_160609_01          MUARA MEDAK 1    BAYUNG LENCIR
# 10  11  BRG_160609_02          MUARA MEDAK 2    BAYUNG LENCIR
# 11  12  BRG_160611_01           KARANG AGUNG            LALAN
#
#              Kabupaten          Provinsi      LAT         LONG  Offset (cm)
# 0   OGAN KOMERING ILIR  SUMATERA SELATAN -3.401407  104.879161          212
# 1   OGAN KOMERING ILIR  SUMATERA SELATAN -3.423133  104.877100          230
# 2   OGAN KOMERING ILIR  SUMATERA SELATAN -3.105565  105.215600          153
# 3   OGAN KOMERING ILIR  SUMATERA SELATAN -3.090585  105.216600          253
# 4   OGAN KOMERING ILIR  SUMATERA SELATAN -3.019940  105.232200          193
# 5   OGAN KOMERING ILIR  SUMATERA SELATAN -3.124240  105.121000          190
# 6   OGAN KOMERING ILIR  SUMATERA SELATAN -3.392495  104.977500          215
# 7   OGAN KOMERING ILIR  SUMATERA SELATAN -3.478628  104.965100          184
# 8   OGAN KOMERING ILIR  SUMATERA SELATAN -3.432265  104.964700          185
# 9       MUSI BANYUASIN  SUMATERA SELATAN -1.795132  103.928600          210
# 10      MUSI BANYUASIN  SUMATERA SELATAN -1.854130  103.902000          230
# 11      MUSI BANYUASIN  SUMATERA SELATAN -2.281653  104.411300          220

# %%
names = ['Kedaton (Demplot)',
         'Kedaton',
         'Padang Sugihan 1 (SM)',
         'Padang Sugihan 2 (SM)',
         'Padang Sugihan 3 (SM)',
         'Air Rumbai',
         'Cinta Jaya 1',
         'Cinta Jaya 2',
         'Cinta Jaya 3',
         'Muara Medak 1',
         'Muara Medak 2',
         'Karang agung']

offset_values = data_offset['Offset (cm)']/100

# %%
offset = {}

for name, values in zip(names, offset_values):
    offset.update({name: values})

offset
# Out:
# {'Kedaton (Demplot)': 2.12,
#  'Kedaton': 2.3,
#  'Padang Sugihan 1 (SM)': 1.53,
#  'Padang Sugihan 2 (SM)': 2.53,
#  'Padang Sugihan 3 (SM)': 1.93,
#  'Air Rumbai': 1.9,
#  'Cinta Jaya 1': 2.15,
#  'Cinta Jaya 2': 1.84,
#  'Cinta Jaya 3': 1.85,
#  'Muara Medak 1': 2.1,
#  'Muara Medak 2': 2.3,
#  'Karang agung': 2.2}

# %%
df['gwl'] = df['gwl'] - offset[location]

# %%
df
# Out:
#                      rain  soil    gwl  temp
# date
# 2018-11-10 11:40:00   0.4   3.2 -1.381  30.7
# 2018-11-10 11:50:00   0.0   3.2 -1.379  30.7
# 2018-11-10 12:00:00   0.0   3.2 -1.372  30.7
# 2018-11-10 12:10:00   0.0   3.2 -1.372  31.1
# 2018-11-10 12:20:00   0.0   3.2 -1.364  31.1
# ...                   ...   ...    ...   ...
# 2020-01-10 02:00:00   0.0  29.0 -0.876  29.5
# 2020-01-10 02:10:00   0.0  29.0 -0.886  29.5
# 2020-01-10 02:20:00   0.0  29.0 -0.881  29.5
# 2020-01-10 02:30:00   0.0  28.6 -0.878  29.5
# 2020-01-10 02:40:00   0.0  29.0 -0.876  29.5
#
# [53324 rows x 4 columns]

# %% [markdown]
# # Explore and plot data

# %%
df.plot(subplots=True, figsize=(25,20))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %%
df.describe()
# Out:
#                rain          soil           gwl          temp
# count  53321.000000  53324.000000  53324.000000  53324.000000
# mean       0.017839     23.381646     -0.609464     30.751718
# std        0.995727     31.360885      0.446894      1.383160
# min        0.000000      0.000000     -2.150000      0.000000
# 25%        0.000000      4.400000     -1.059000     29.800000
# 50%        0.000000      7.900001     -0.629000     30.700000
# 75%        0.000000     23.000000     -0.202000     31.700000
# max      175.800000     92.500000      0.309000     34.200000

# %%
plt.figure(figsize=(25,5))
plt.plot(df['gwl'])
plt.axhline(df['gwl'].mean())

# %%
df['gwl'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Anomaly detection
#
# Set outlier and missing value to NA
#
# ![image](https://miro.medium.com/v2/resize:fit:1100/format:webp/1*5kUgnjnrfJhxL47BeXl1JQ.png)

# %% [markdown]
# ## FBProphet

# %%
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
model = Prophet(interval_width=0.99, yearly_seasonality=True, weekly_seasonality=True)

# %%
df_fb = pd.read_pickle("clean/" + location + ".pkl")
df_fb
# Out:
#            location                date  rain  soil    gwl  temp
# 0      Cinta Jaya 1 2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 1      Cinta Jaya 1 2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2      Cinta Jaya 1 2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 3      Cinta Jaya 1 2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 4      Cinta Jaya 1 2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...             ...                 ...   ...   ...    ...   ...
# 53319  Cinta Jaya 1 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 53320  Cinta Jaya 1 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 53321  Cinta Jaya 1 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 53322  Cinta Jaya 1 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 53323  Cinta Jaya 1 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# [53324 rows x 6 columns]

# %%
df_fb = df_fb.drop(['location', 'rain', 'soil', 'temp'], axis=1)
df_fb.columns = ['ds', 'y']
df_fb
# Out:
#                        ds      y
# 0     2018-11-10 11:40:00  0.769
# 1     2018-11-10 11:50:00  0.771
# 2     2018-11-10 12:00:00  0.778
# 3     2018-11-10 12:10:00  0.778
# 4     2018-11-10 12:20:00  0.786
# ...                   ...    ...
# 53319 2020-01-10 02:00:00  1.274
# 53320 2020-01-10 02:10:00  1.264
# 53321 2020-01-10 02:20:00  1.269
# 53322 2020-01-10 02:30:00  1.272
# 53323 2020-01-10 02:40:00  1.274
#
# [53324 rows x 2 columns]

# %%
model.fit(df_fb)
# Out:
# 08:07:01 - cmdstanpy - INFO - Chain [1] start processing
# 08:08:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast = model.predict(df_fb)
model.plot(forecast);

# %%
model.plot_components(forecast);

# %%
# Merge actual and predicted values
performance = pd.merge(df_fb, forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']], on='ds')

# Check MAE value
performance_MAE = mean_absolute_error(performance['y'], performance['yhat'])
print(f'The MAE for the model is {performance_MAE}')

# Check MAPE value
performance_MAPE = mean_absolute_percentage_error(performance['y'], performance['yhat'])
print(f'The MAPE for the model is {performance_MAPE}')
# Out:
# The MAE for the model is 0.042998768506425936
# The MAPE for the model is 29955896466903.0

# %%
# Create an anomaly indicator
performance['anomaly'] = performance.apply(lambda rows: 1 if ((rows.y<rows.yhat_lower)|(rows.y>rows.yhat_upper)) else 0, axis = 1)

# Check the number of anomalies
performance['anomaly'].value_counts()
# Out:
# 0    53091
# 1      233
# Name: anomaly, dtype: int64

# %%
# Take a look at the anomalies
anomalies = performance[performance['anomaly']==1].sort_values(by='ds')
anomalies
# Out:
#                        ds      y      yhat  yhat_lower  yhat_upper  anomaly
# 0     2018-11-10 11:40:00  0.769  1.478323    1.196742    1.810711        1
# 1     2018-11-10 11:50:00  0.771  1.478293    1.138995    1.785047        1
# 2     2018-11-10 12:00:00  0.778  1.478285    1.084769    1.826218        1
# 3     2018-11-10 12:10:00  0.778  1.478301    1.152122    1.792394        1
# 4     2018-11-10 12:20:00  0.786  1.478339    1.156068    1.760763        1
# ...                   ...    ...       ...         ...         ...      ...
# 17305 2019-05-01 22:00:00  0.000  1.974365    1.656433    2.326612        1
# 17306 2019-05-01 22:10:00  0.000  1.974450    1.629174    2.265210        1
# 17307 2019-05-01 22:20:00  0.000  1.974568    1.657635    2.327345        1
# 17308 2019-05-01 22:30:00  0.000  1.974719    1.667225    2.298821        1
# 17309 2019-05-01 22:40:00  0.000  1.974903    1.638428    2.311363        1
#
# [233 rows x 6 columns]

# %%
import seaborn as sns

sns.scatterplot(x='ds', y='y', data=performance, hue='anomaly')
sns.lineplot(x='ds', y='yhat', data=performance, color='black')
# Out:
# <AxesSubplot:xlabel='ds', ylabel='y'>

# %%
performance
# Out:
#                        ds      y      yhat  yhat_lower  yhat_upper  anomaly
# 0     2018-11-10 11:40:00  0.769  1.478323    1.196742    1.810711        1
# 1     2018-11-10 11:50:00  0.771  1.478293    1.138995    1.785047        1
# 2     2018-11-10 12:00:00  0.778  1.478285    1.084769    1.826218        1
# 3     2018-11-10 12:10:00  0.778  1.478301    1.152122    1.792394        1
# 4     2018-11-10 12:20:00  0.786  1.478339    1.156068    1.760763        1
# ...                   ...    ...       ...         ...         ...      ...
# 53319 2020-01-10 02:00:00  1.274  1.164972    0.836850    1.471260        0
# 53320 2020-01-10 02:10:00  1.264  1.164948    0.796975    1.503244        0
# 53321 2020-01-10 02:20:00  1.269  1.164865    0.862445    1.515753        0
# 53322 2020-01-10 02:30:00  1.272  1.164727    0.820740    1.518065        0
# 53323 2020-01-10 02:40:00  1.274  1.164540    0.853565    1.499841        0
#
# [53324 rows x 6 columns]

# %% [markdown]
# ## Isolation Forest

# %%
import seaborn as sns
from sklearn.ensemble import IsolationForest

# %%
df_if = df
df_if
# Out:
#                      rain  soil    gwl  temp outliers
# date
# 2018-11-10 11:40:00   0.4   3.2 -1.381  30.7      NaN
# 2018-11-10 11:50:00   0.0   3.2 -1.379  30.7      NaN
# 2018-11-10 12:00:00   0.0   3.2 -1.372  30.7      NaN
# 2018-11-10 12:10:00   0.0   3.2 -1.372  31.1      NaN
# 2018-11-10 12:20:00   0.0   3.2 -1.364  31.1      NaN
# ...                   ...   ...    ...   ...      ...
# 2020-01-10 02:00:00   0.0  29.0 -0.876  29.5      NaN
# 2020-01-10 02:10:00   0.0  29.0 -0.886  29.5      NaN
# 2020-01-10 02:20:00   0.0  29.0 -0.881  29.5      NaN
# 2020-01-10 02:30:00   0.0  28.6 -0.878  29.5      NaN
# 2020-01-10 02:40:00   0.0  29.0 -0.876  29.5      NaN
#
# [53324 rows x 5 columns]

# %%
model_if = IsolationForest(contamination=float(0.004), random_state=42)

# %%
model_if.fit(df[['gwl']])
# Out:
# c:\users\akimp\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.004, random_state=42)

# %%
df_if['anomaly'] = model_if.predict(df[['gwl']])
df_if
# Out:
#                      rain  soil    gwl  temp outliers  anomaly
# date
# 2018-11-10 11:40:00   0.4   3.2 -1.381  30.7      NaN       -1
# 2018-11-10 11:50:00   0.0   3.2 -1.379  30.7      NaN       -1
# 2018-11-10 12:00:00   0.0   3.2 -1.372  30.7      NaN       -1
# 2018-11-10 12:10:00   0.0   3.2 -1.372  31.1      NaN       -1
# 2018-11-10 12:20:00   0.0   3.2 -1.364  31.1      NaN       -1
# ...                   ...   ...    ...   ...      ...      ...
# 2020-01-10 02:00:00   0.0  29.0 -0.876  29.5      NaN        1
# 2020-01-10 02:10:00   0.0  29.0 -0.886  29.5      NaN        1
# 2020-01-10 02:20:00   0.0  29.0 -0.881  29.5      NaN        1
# 2020-01-10 02:30:00   0.0  28.6 -0.878  29.5      NaN        1
# 2020-01-10 02:40:00   0.0  29.0 -0.876  29.5      NaN        1
#
# [53324 rows x 6 columns]

# %%
df_if[df_if['anomaly']==-1]['gwl']
# Out:
# date
# 2018-11-10 11:40:00   -1.381
# 2018-11-10 11:50:00   -1.379
# 2018-11-10 12:00:00   -1.372
# 2018-11-10 12:10:00   -1.372
# 2018-11-10 12:20:00   -1.364
#                        ...
# 2019-05-01 22:00:00   -2.150
# 2019-05-01 22:10:00   -2.150
# 2019-05-01 22:20:00   -2.150
# 2019-05-01 22:30:00   -2.150
# 2019-05-01 22:40:00   -2.150
# Name: gwl, Length: 212, dtype: float64

# %%
plt.figure(figsize=(25,5))
plt.plot(df['gwl'])
plt.scatter(df_if[df_if['anomaly']==-1].index, df_if[df_if['anomaly']==-1]['gwl'], color='orange')

# %% [markdown]
# ## Thresholding

# %%
df_th = pd.read_pickle("clean/" + location + ".pkl")
df_th
# Out:
#            location                date  rain  soil    gwl  temp
# 0      Cinta Jaya 1 2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 1      Cinta Jaya 1 2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2      Cinta Jaya 1 2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 3      Cinta Jaya 1 2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 4      Cinta Jaya 1 2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...             ...                 ...   ...   ...    ...   ...
# 53319  Cinta Jaya 1 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 53320  Cinta Jaya 1 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 53321  Cinta Jaya 1 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 53322  Cinta Jaya 1 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 53323  Cinta Jaya 1 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# [53324 rows x 6 columns]

# %%
df_th = df_th.drop(['location'], axis=1)
df_th
# Out:
#                      date  rain  soil    gwl  temp
# 0     2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 1     2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2     2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 3     2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 4     2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...                   ...   ...   ...    ...   ...
# 53319 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 53320 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 53321 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 53322 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 53323 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# [53324 rows x 5 columns]

# %%
ma = [5, 10, 20, 30, 40, 50, 100]

for n in ma:
    df_th[('gwl_ma%d' % n)] = df_th['gwl'].rolling(n).mean().ffill().bfill()

df_th
# Out:
#                      date  rain  soil    gwl  temp  gwl_ma5  gwl_ma10  \
# 0     2018-11-10 11:40:00   0.4   3.2  0.769  30.7   0.7764    0.7852
# 1     2018-11-10 11:50:00   0.0   3.2  0.771  30.7   0.7764    0.7852
# 2     2018-11-10 12:00:00   0.0   3.2  0.778  30.7   0.7764    0.7852
# 3     2018-11-10 12:10:00   0.0   3.2  0.778  31.1   0.7764    0.7852
# 4     2018-11-10 12:20:00   0.0   3.2  0.786  31.1   0.7764    0.7852
# ...                   ...   ...   ...    ...   ...      ...       ...
# 53319 2020-01-10 02:00:00   0.0  29.0  1.274  29.5   1.2708    1.2700
# 53320 2020-01-10 02:10:00   0.0  29.0  1.264  29.5   1.2692    1.2700
# 53321 2020-01-10 02:20:00   0.0  29.0  1.269  29.5   1.2702    1.2700
# 53322 2020-01-10 02:30:00   0.0  28.6  1.272  29.5   1.2702    1.2700
# 53323 2020-01-10 02:40:00   0.0  29.0  1.274  29.5   1.2706    1.2705
#
#        gwl_ma20  gwl_ma30  gwl_ma40  gwl_ma50  gwl_ma100
# 0       0.80090  0.815933  0.830750   0.84440    1.08191
# 1       0.80090  0.815933  0.830750   0.84440    1.08191
# 2       0.80090  0.815933  0.830750   0.84440    1.08191
# 3       0.80090  0.815933  0.830750   0.84440    1.08191
# 4       0.80090  0.815933  0.830750   0.84440    1.08191
# ...         ...       ...       ...       ...        ...
# 53319   1.26915  1.267400  1.266100   1.26484    1.25625
# 53320   1.26890  1.267467  1.266150   1.26492    1.25659
# 53321   1.26890  1.267633  1.266275   1.26510    1.25698
# 53322   1.26905  1.267900  1.266525   1.26550    1.25740
# 53323   1.26955  1.268233  1.266875   1.26578    1.25776
#
# [53324 rows x 12 columns]

# %%
plt.figure(figsize=(30,10))
plt.plot(df_th['gwl'])

for n in ma:
    plt.plot(df_th[('gwl_ma%d' % n)])
    
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Boxplot

# %%
plt.plot(df['gwl'])

# %%
plt.boxplot(df['gwl'])

# %% [markdown]
# # Anomaly removal
#
# Using Facebook Prophets anomaly detection to find outliers in time series. Outliers will be removed for imputation

# %%
performance

# %%
df['anomaly'] = performance['anomaly']
df

# %%
df['gwl'].mask(df['anomaly']==1, np.nan, inplace=True)
df

# %%
plt.plot(df['gwl'])

# %%
plt.hist(df['gwl'])

# %%
df['gwl'].isna().sum()

# %%
# df.to_pickle("anomaly/" + location + ".pkl")

# %%
names
