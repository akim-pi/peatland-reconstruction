# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import xlrd

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/Skripsi Abdul Hakim/piton skripsi
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/Skripsi Abdul Hakim/piton skripsi'
# /content/drive/MyDrive/Skripsi Abdul Hakim/piton skripsi

# %%
location = "Cinta Jaya 1"
df = pd.read_pickle("clean/" + location + ".pkl")
df
# Out:
#            location                date  rain  soil    gwl  temp
# 0      Cinta Jaya 1 2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 1      Cinta Jaya 1 2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2      Cinta Jaya 1 2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 3      Cinta Jaya 1 2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 4      Cinta Jaya 1 2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...             ...                 ...   ...   ...    ...   ...
# 53319  Cinta Jaya 1 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 53320  Cinta Jaya 1 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 53321  Cinta Jaya 1 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 53322  Cinta Jaya 1 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 53323  Cinta Jaya 1 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# [53324 rows x 6 columns]

# %%
df = df.set_index('date')
df = df.asfreq('10T', fill_value=np.nan)
df.reset_index(inplace=True)

# %%
df
# Out:
#                      date      location  rain  soil    gwl  temp
# 0     2018-11-10 11:40:00  Cinta Jaya 1   0.4   3.2  0.769  30.7
# 1     2018-11-10 11:50:00  Cinta Jaya 1   0.0   3.2  0.771  30.7
# 2     2018-11-10 12:00:00  Cinta Jaya 1   0.0   3.2  0.778  30.7
# 3     2018-11-10 12:10:00  Cinta Jaya 1   0.0   3.2  0.778  31.1
# 4     2018-11-10 12:20:00  Cinta Jaya 1   0.0   3.2  0.786  31.1
# ...                   ...           ...   ...   ...    ...   ...
# 61286 2020-01-10 02:00:00  Cinta Jaya 1   0.0  29.0  1.274  29.5
# 61287 2020-01-10 02:10:00  Cinta Jaya 1   0.0  29.0  1.264  29.5
# 61288 2020-01-10 02:20:00  Cinta Jaya 1   0.0  29.0  1.269  29.5
# 61289 2020-01-10 02:30:00  Cinta Jaya 1   0.0  28.6  1.272  29.5
# 61290 2020-01-10 02:40:00  Cinta Jaya 1   0.0  29.0  1.274  29.5
#
# [61291 rows x 6 columns]

# %%
plt.plot(df.index, df['gwl'])

# %%
df
# Out:
#                          location  rain  soil    gwl  temp
# date
# 2018-11-10 11:40:00  Cinta Jaya 1   0.4   3.2  0.769  30.7
# 2018-11-10 11:50:00  Cinta Jaya 1   0.0   3.2  0.771  30.7
# 2018-11-10 12:00:00  Cinta Jaya 1   0.0   3.2  0.778  30.7
# 2018-11-10 12:10:00  Cinta Jaya 1   0.0   3.2  0.778  31.1
# 2018-11-10 12:20:00  Cinta Jaya 1   0.0   3.2  0.786  31.1
# ...                           ...   ...   ...    ...   ...
# 2020-01-10 02:00:00  Cinta Jaya 1   0.0  29.0  1.274  29.5
# 2020-01-10 02:10:00  Cinta Jaya 1   0.0  29.0  1.264  29.5
# 2020-01-10 02:20:00  Cinta Jaya 1   0.0  29.0  1.269  29.5
# 2020-01-10 02:30:00  Cinta Jaya 1   0.0  28.6  1.272  29.5
# 2020-01-10 02:40:00  Cinta Jaya 1   0.0  29.0  1.274  29.5
#
# [61291 rows x 5 columns]

# %%
df

# %%
df['location'] = 'Cinta Jaya 1'

# %%
df
# Out:
#                      date      location  rain  soil    gwl  temp
# 0     2018-11-10 11:40:00  Cinta Jaya 1   0.4   3.2  0.769  30.7
# 1     2018-11-10 11:50:00  Cinta Jaya 1   0.0   3.2  0.771  30.7
# 2     2018-11-10 12:00:00  Cinta Jaya 1   0.0   3.2  0.778  30.7
# 3     2018-11-10 12:10:00  Cinta Jaya 1   0.0   3.2  0.778  31.1
# 4     2018-11-10 12:20:00  Cinta Jaya 1   0.0   3.2  0.786  31.1
# ...                   ...           ...   ...   ...    ...   ...
# 61286 2020-01-10 02:00:00  Cinta Jaya 1   0.0  29.0  1.274  29.5
# 61287 2020-01-10 02:10:00  Cinta Jaya 1   0.0  29.0  1.264  29.5
# 61288 2020-01-10 02:20:00  Cinta Jaya 1   0.0  29.0  1.269  29.5
# 61289 2020-01-10 02:30:00  Cinta Jaya 1   0.0  28.6  1.272  29.5
# 61290 2020-01-10 02:40:00  Cinta Jaya 1   0.0  29.0  1.274  29.5
#
# [61291 rows x 6 columns]

# %%
df[df['gwl'].isna()]
# Out:
#                      date      location  rain  soil  gwl  temp
# 81    2018-11-11 01:10:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 99    2018-11-11 04:10:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 612   2018-11-14 17:40:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 618   2018-11-14 18:40:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 619   2018-11-14 18:50:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# ...                   ...           ...   ...   ...  ...   ...
# 61106 2020-01-08 20:00:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 61107 2020-01-08 20:10:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 61108 2020-01-08 20:20:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 61109 2020-01-08 20:30:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
# 61128 2020-01-08 23:40:00  Cinta Jaya 1   NaN   NaN  NaN   NaN
#
# [7967 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61291 entries, 0 to 61290
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      61291 non-null  datetime64[ns]
#  1   location  61291 non-null  object
#  2   rain      53321 non-null  float64
#  3   soil      53324 non-null  float64
#  4   gwl       53324 non-null  float64
#  5   temp      53324 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 2.8+ MB

# %%
(df['gwl'] == 0.0).sum()
# Out:
# 8148

# %%
df1 = pd.period_range(start='2018-11-10 11:40:00', end='2020-01-10 02:40:00', freq='10min')
df1
# Out:
# PeriodIndex(['2018-11-10 11:40', '2018-11-10 11:50', '2018-11-10 12:00',
#              '2018-11-10 12:10', '2018-11-10 12:20', '2018-11-10 12:30',
#              '2018-11-10 12:40', '2018-11-10 12:50', '2018-11-10 13:00',
#              '2018-11-10 13:10',
#              ...
#              '2020-01-10 01:10', '2020-01-10 01:20', '2020-01-10 01:30',
#              '2020-01-10 01:40', '2020-01-10 01:50', '2020-01-10 02:00',
#              '2020-01-10 02:10', '2020-01-10 02:20', '2020-01-10 02:30',
#              '2020-01-10 02:40'],
#             dtype='period[10T]', length=61291)

# %%
df = df.set_index(df['date'])
df
# Out:
#                          location                date  rain  soil    gwl  temp
# date
# 2018-11-10 11:40:00  Cinta Jaya 1 2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 2018-11-10 11:50:00  Cinta Jaya 1 2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2018-11-10 12:00:00  Cinta Jaya 1 2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 2018-11-10 12:10:00  Cinta Jaya 1 2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 2018-11-10 12:20:00  Cinta Jaya 1 2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...                           ...                 ...   ...   ...    ...   ...
# 2020-01-10 02:00:00  Cinta Jaya 1 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 2020-01-10 02:10:00  Cinta Jaya 1 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 2020-01-10 02:20:00  Cinta Jaya 1 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 2020-01-10 02:30:00  Cinta Jaya 1 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 2020-01-10 02:40:00  Cinta Jaya 1 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# ...

# %%
df.index = pd.DatetimeIndex(df.index)
df.asfreq('10min')
# df.reindex(df1, fill_value=0)
# Out:
#                          location                date  rain  soil    gwl  temp
# date
# 2018-11-10 11:40:00  Cinta Jaya 1 2018-11-10 11:40:00   0.4   3.2  0.769  30.7
# 2018-11-10 11:50:00  Cinta Jaya 1 2018-11-10 11:50:00   0.0   3.2  0.771  30.7
# 2018-11-10 12:00:00  Cinta Jaya 1 2018-11-10 12:00:00   0.0   3.2  0.778  30.7
# 2018-11-10 12:10:00  Cinta Jaya 1 2018-11-10 12:10:00   0.0   3.2  0.778  31.1
# 2018-11-10 12:20:00  Cinta Jaya 1 2018-11-10 12:20:00   0.0   3.2  0.786  31.1
# ...                           ...                 ...   ...   ...    ...   ...
# 2020-01-10 02:00:00  Cinta Jaya 1 2020-01-10 02:00:00   0.0  29.0  1.274  29.5
# 2020-01-10 02:10:00  Cinta Jaya 1 2020-01-10 02:10:00   0.0  29.0  1.264  29.5
# 2020-01-10 02:20:00  Cinta Jaya 1 2020-01-10 02:20:00   0.0  29.0  1.269  29.5
# 2020-01-10 02:30:00  Cinta Jaya 1 2020-01-10 02:30:00   0.0  28.6  1.272  29.5
# 2020-01-10 02:40:00  Cinta Jaya 1 2020-01-10 02:40:00   0.0  29.0  1.274  29.5
#
# ...

# %%
plt.scatter(df['date'], df['gwl'])

# %%
df1
# Out:
# PeriodIndex(['2018-11-10 11:40', '2018-11-10 11:50', '2018-11-10 12:00',
#              '2018-11-10 12:10', '2018-11-10 12:20', '2018-11-10 12:30',
#              '2018-11-10 12:40', '2018-11-10 12:50', '2018-11-10 13:00',
#              '2018-11-10 13:10',
#              ...
#              '2020-01-10 01:10', '2020-01-10 01:20', '2020-01-10 01:30',
#              '2020-01-10 01:40', '2020-01-10 01:50', '2020-01-10 02:00',
#              '2020-01-10 02:10', '2020-01-10 02:20', '2020-01-10 02:30',
#              '2020-01-10 02:40'],
#             dtype='period[10T]', length=61291)

# %%
df = pd.read_table("data/provinsi_sumsel (1).txt", delimiter=";",
                  names=['code', 'machine', 'provinsi', 'kabupaten', 'kecamatan', 'location', 'date', 'rain', 'soil', 'gwl', 'temp'],
                  header=None)
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,7,8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  code    machine          provinsi           kabupaten  \
# 0       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 1       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 2       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 3       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# 4       BRG_160205_01  286823772  SUMATERA SELATAN  OGAN KOMERING ILIR
# ...               ...        ...               ...                 ...
# 660993  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660994  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# 660995  BRG_160611_01  286827114  SUMATERA SELATAN      MUSI BANYUASIN
# ...

# %%
df.iloc[385087]
# Out:
# code              BRG_160224_01
# machine               286823786
# provinsi       SUMATERA SELATAN
# kabupaten    OGAN KOMERING ILIR
# kecamatan             PEDAMARAN
# location           Cinta Jaya 1
# date                        Lat
# rain                        Lon
# soil                         SG
# gwl                          FW
# temp                         BT
# Name: 385087, dtype: object

# %%
test = df.iloc[[385087, 429289]]

# %%
test.to_clipboard(excel=True)

# %%
	code	machine	provinsi	kabupaten	kecamatan	location	date	rain	soil	gwl	temp
385087	BRG_160224_01	286823786	SUMATERA SELATAN	OGAN KOMERING ILIR	PEDAMARAN	Cinta Jaya 1	Lat	Lon	SG	FW	BT
429289	BRG_160224_02	286823412	SUMATERA SELATAN	OGAN KOMERING ILIR	PEDAMARAN	Cinta Jaya 2	D	RR	SM	WL	ST
